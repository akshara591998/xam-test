# %%
#importing the required libraries
import pandas as pd
import numpy as np
#import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pyplot.graph_objects as go
import plotly.express as px

#plt.rcParams['figure.figsize'] = (16,18)
#plt.style.use('fivethirtyeight')


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data_car.csv")

df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
#checking the no of rows and colms in the dataset
print('Shape of the Data: ', (df.shape))
# Out:
# Shape of the Data:  (11914, 16)

# %%
#Checking the basic information of dataset like count, datatypes of columns (categorical or numerical)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
#Type of Data
'''
#   Column             Non-Null Count  Dtype      Categorical/Numerical
---  ------             --------------  -----  
 0   Make               11914 non-null  object    Categorical
 1   Model              11914 non-null  object    Categorical
 2   Year               11914 non-null  int64     Numerical Discrete
 3   Engine Fuel Type   11911 non-null  object    Categorical
 4   Engine HP          11845 non-null  float64   Numerical Discrete
 5   Engine Cylinders   11884 non-null  float64   Numerical Continuous
 6   Transmission Type  11914 non-null  object    Categorical
 7   Driven_Wheels      11914 non-null  object    Categorical
 8   Number of Doors    11908 non-null  float64   Numerical Discrete
 9   Market Category    8172 non-null   object    Categorical
 10  Vehicle Size       11914 non-null  object    Categorical
 11  Vehicle Style      11914 non-null  object    Categorical 
 12  highway MPG        11914 non-null  int64     Numerical Discrete
 13  city mpg           11914 non-null  int64     Numerical Discrete
 14  Popularity         11914 non-null  int64     Numerical Discrete
 15  MSRP               11914 non-null  int64     Numerical Continuous

 '''
# Out:
# '\n#   Column             Non-Null Count  Dtype      Categorical/Numerical\n---  ------             --------------  -----  \n 0   Make               11914 non-null  object    Categorical\n 1   Model              11914 non-null  object    Categorical\n 2   Year               11914 non-null  int64     Numerical Discrete\n 3   Engine Fuel Type   11911 non-null  object    Categorical\n 4   Engine HP          11845 non-null  float64   Numerical Discrete\n 5   Engine Cylinders   11884 non-null  float64   Numerical Continuous\n 6   Transmission Type  11914 non-null  object    Categorical\n 7   Driven_Wheels      11914 non-null  object    Categorical\n 8   Number of Doors    11908 non-null  float64   Numerical Discrete\n 9   Market Category    8172 non-null   object    Categorical\n 10  Vehicle Size       11914 non-null  object    Categorical\n 11  Vehicle Style      11914 non-null  object    Categorical \n 12  highway MPG        11914 non-null  int64     Numerical Discrete\n 13  city mpg   
# ...

# %% [markdown]
# # checking duplicates in our dataset

# %%
#Checking for duplicates

display("Total number of of Duplicates present in data: %s" %df.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 715'

# %%
#Removing duplicates if any in the data
df.drop_duplicates(inplace=True)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
#Checking for duplicates again
display("Total number of of Duplicates present in data: %s" %df.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 0'

# %%
#Checking how many rows are there in the dataset after removing the duplicates
print('Shape of the Data after duplicates removal: ', (df.shape))
# Out:
# Shape of the Data after duplicates removal:  (11199, 16)

# %%
df=df.reset_index(drop=True)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11194    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11195    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11196    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11197    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11198  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # checking missing values in dataset

# %%
print("Number of Missing Values in our data set\n")
missing_df = df.isnull().sum().to_frame().reset_index().rename({"index" : 'Variable', 0: 'Missing Values'}, axis =1)
display(missing_df.style.background_gradient('gnuplot2_r'))
print("\n Percentage of Missing Values in our data set")
display((df.isnull().sum() / (len(df.index)) * 100).head(20).to_frame().rename({0:'Count'}, axis = 1).style.background_gradient('gnuplot2_r'))
round((df.isnull().sum() / (len(df.index)) * 100) , 2).plot(kind = 'barh',color ='maroon')

plt.title("Percentage of Missing values");
# Out:
# Number of Missing Values in our data set
# <style type="text/css">
# #T_ed6fd_row0_col1, #T_ed6fd_row1_col1, #T_ed6fd_row2_col1, #T_ed6fd_row3_col1, #T_ed6fd_row6_col1, #T_ed6fd_row7_col1, #T_ed6fd_row8_col1, #T_ed6fd_row10_col1, #T_ed6fd_row11_col1, #T_ed6fd_row12_col1, #T_ed6fd_row13_col1, #T_ed6fd_row14_col1, #T_ed6fd_row15_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ed6fd_row4_col1 {
#   background-color: #ffffc0;
#   color: #000000;
# }
# #T_ed6fd_row5_col1 {
#   background-color: #ffffe6;
#   color: #000000;
# }
# #T_ed6fd_row9_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed6fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed6fd_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_ed6fd_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # treating missing values

# %%
#We will use Mode to fill up missing values in Categorical columns
df['Market Category'].fillna(df['Market Category'].mode()[0], inplace = True)
df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode()[0], inplace = True)
   

#We will use mean to fill up missing values in Numerical Continuous columns
df['Engine HP'].fillna(df['Engine HP'].mean(), inplace = True)

#We will use median to fill up missing values in Ordinal Numerical Discrete columns
df['Engine Cylinders'].fillna(df['Engine Cylinders'].median(), inplace = True)
df['Number of Doors'].fillna(df['Number of Doors'].median(), inplace = True)

#Checking Missing Values after imputing
display(df.isnull().sum().to_frame().reset_index().rename({'index' : 'Variables', 0: 'Missing Values'}, axis =1).style.background_gradient('copper_r'))
# Out:
# <style type="text/css">
# #T_09931_row0_col1, #T_09931_row1_col1, #T_09931_row2_col1, #T_09931_row3_col1, #T_09931_row4_col1, #T_09931_row5_col1, #T_09931_row6_col1, #T_09931_row7_col1, #T_09931_row8_col1, #T_09931_row9_col1, #T_09931_row10_col1, #T_09931_row11_col1, #T_09931_row12_col1, #T_09931_row13_col1, #T_09931_row14_col1, #T_09931_row15_col1 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# </style>
# <table id="T_09931">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09931_level0_col0" class="col_heading level0 col0" >Variables</th>
#       <th id="T_09931_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09931_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09931_row0_col0" class="data row0 col0" >Make</td>
#       <td id="T_09931_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Data Description and initial cleaning

# %%
#Checking Statistics Summary of numerical columns
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11199.000000  11199.000000      11199.000000     11199.000000
# mean    2010.714528    253.388859          5.666845         3.454416
# std        7.228211    109.811049          1.794696         0.872804
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    172.000000          4.000000         2.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    303.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11199.000000  11199.000000  11199.000000  1.119900e+04
# mean      26.610590     19.731851   1558.483347  4.192593e+04
# std        8.977641      9.177555   1445.668872  6.153505e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
#Checking Summary of categorical columns
df.describe(include="object")
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11199           11199             11199             11199
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1083             156              6661              7932
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11199           11199        11199         11199
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4354            4451         4395          2843

# %% [markdown]
# # Cleaning strings in columns names

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# # handling categorical data

# %%
# If the data is Categorical, check with reference to domain whether the following parameters are valid or not:
#      1. Check the unique values.
#      2. Check if there are Spelling errors or not.
#      3. Check if any unusual category exists, if yes then remove it.

# %% [markdown]
# # making list of categorical coloumns

# %%
#Making List of Categorical Columns

categorical = list(df.dtypes[df.dtypes == 'object'].index)
categorical
# Other methods 
# list(df.select_dtypes(include = 'O').columns)
# [col for col in df.columns if df[col].dtype == 'object']
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %% [markdown]
# # cleaning categorical data in our dataset

# %%
#Cleaning Categorical Data in our data set

for col in categorical:
    df[col] = df[col].str.lower().str.replace(" ", "_")
    
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# # unique values in categorical coloumns

# %%
#Checkin the unique values in categorical columns
for col in categorical:
    print(col)
    print(df[col].unique())
    print("Number of unique classes ",df[col].nunique())
    print('\n')
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler' 'nissan' 'volvo' 'mazda'
#  'mitsubishi' 'ferrari' 'alfa_romeo' 'toyota' 'mclaren' 'maybach'
#  'pontiac' 'porsche' 'saab' 'gmc' 'hyundai' 'plymouth' 'honda'
#  'oldsmobile' 'suzuki' 'ford' 'cadillac' 'kia' 'bentley' 'chevrolet'
#  'dodge' 'lamborghini' 'lincoln' 'subaru' 'volkswagen' 'spyker' 'buick'
#  'acura' 'rolls-royce' 'maserati' 'lexus' 'aston_martin' 'land_rover'
#  'lotus' 'infiniti' 'scion' 'genesis' 'hummer' 'tesla' 'bugatti']
# Number of unique classes  48
#
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class' '2_series' '200'
#  '200sx' '240sx' '240' '2' '3_series_gran_turismo' '3_series' '300-class'
#  '3000gt' '300' '300m' '300zx' '323' '350-class' '350z' '360' '370z' '3'
#  '4_series_gran_coupe' '4_series' '400-class' '420-class' '456m'
#  '458_italia' '4c' '4runner' '5_series_gran_turismo' '5_series'
#  '500-class' '500e' '500' '500l' '500x' '550' '560-class' '570s' '575m'
# ...

# %% [markdown]
# # removing unusual category from transmission type

# %%
df.drop(df.loc[df['transmission_type']=='unknown'].index, inplace=True)
df.shape
# Out:
# (11187, 16)

# %%
df.reset_index(drop=True)
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11182    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11183    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11184    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11185    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11186  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %% [markdown]
# # handling numerical data

# %%
# If the data is CONTINOUS, check with reference to domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not.
#      2. Positive Numbers are allowed or not.
#      3. Decimals are allowed or just Integers are Expected.
# If the data is DISCRETE, check with reference to domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not.
#      2. Positive Numbers are allowed or not.
#      3. Decimals are allowed or just Integers are Expected.
#      4. Check whether the number falls in the specified Range defined by DOMAIN

# %% [markdown]
# # checking negative values in numerical col

# %%
#Checking for negative values in Numerical Columns
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
    df[df[i]<0]
    print("Records with Negative values in %s : " %i,df[df[i]<0])
    print('\n')
# Out:
# Records with Negative values in year :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in engine_hp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in engine_cylinders :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with Negative values in number_of_doors :  Empty DataFrame
# ...

# %% [markdown]
# # checking if col hve values as 0

# %%
#Checking for 0 values in Year
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
   df[df[i]==0]
   print("Records with 0 values in %s : " %i,df[df[i]==0])
   print('\n')
    #ax = sns.distplot(df[i], color = 'purple')
    #plt.title("Negative values in %s" %i, fontsize = 20)
    #plt.xlabel(" ")
    #plt.ylabel(" ")
    #plt.xticks(fontsize = 15)
    #plt.show();
# Out:
# Records with 0 values in year :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in engine_hp :  Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp]
# Index: []
#
#
# Records with 0 values in engine_cylinders :                 make                   model  year engine_fuel_type  \
# 520            fiat                    500e  2015         electric
# 521            fiat                    500e  2016         electric
# 522            fiat                    500e  2017         electric
# 1642  mercedes-benz  b-class_electric_drive  2015         electric
# ...

# %% [markdown]
# # checking corelation between the variables

# %%
#Correlation Matrix of Data
df.corr().style.background_gradient("copper_r")
# Out:
# <style type="text/css">
# #T_b1bfc_row0_col0, #T_b1bfc_row1_col1, #T_b1bfc_row2_col2, #T_b1bfc_row3_col3, #T_b1bfc_row4_col4, #T_b1bfc_row5_col5, #T_b1bfc_row6_col6, #T_b1bfc_row7_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col1 {
#   background-color: #9a623e;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col2 {
#   background-color: #cc8152;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col3 {
#   background-color: #ce8253;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col4 {
#   background-color: #955f3c;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col5 {
#   background-color: #a46842;
#   color: #f1f1f1;
# }
# #T_b1bfc_row0_col6, #T_b1bfc_row1_col5 {
#   background-color: #ffad6e;
#   color: #000000;
# }
# #T_b1bfc_row0_col7 {
#   background-color: #d68756;
#   color: #f1f1f1;
# }
# #T_b1bfc_row1_col0 {
#   background-color: #cb8052;
#   color: #f1f1f1;
# }
# #T_b1bfc_row1_col2 {
#   background-color: #2c1c12;
#   color: #f1f1f1;
# }
# ...

# %%
sns.heatmap(df.corr(),annot = True, lw = 0.1);

# %% [markdown]
# Observarion
# m
# s
# r
# p
#   is the dependent variable.
# Variables engine_hp and engine_cylinders has the highest correlation with dependent variable.
# Multicollinearity exits in our data set. We can Observe the correlation between engine_hp & engine_cylinders and highway_mpg & city_mpg

# %% [markdown]
# # visualisations

# %%
Checking Relation between all variables</div>

# %% [markdown]
# # distribution and relationship of numerical variables with dependent variable

# %%
numerical = [col for col in df.columns if col not in categorical]
for i in numerical:
   
    ax = sns.distplot(df[i], color = 'purple')
    plt.title("Distribution of %s" %i, fontsize = 20)
    plt.xlabel(" ")
    plt.ylabel(" ")
    plt.xticks(fontsize = 20)
    plt.show();
    print('\n')
# Out:
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Plotting a pairplot to check the relationship between the variables
sns.pairplot(df)

# %%
#scatterplot to understand the relationship between numerical variables and dependend variable MSRP
nrows = 2
ncols = 4
i = 0
fig, ax = plt.subplots(nrows, ncols, figsize = (16,8),)
for row in range(nrows):
    for col in range(ncols):
        sns.scatterplot(df[numerical].iloc[:, i],df['msrp'],ax = ax[row, col],color = 'maroon' ).set(ylabel = '')
        plt.tight_layout()
        i += 1
# Out:
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
#Creating a function for ordering the groups in a column as per their frequency
def sort_order(column):
    orders = (df.groupby([column]).mean().sort_values(by ='msrp', ascending = False)).index
    return orders

# %%
#Looping over categorical variables to check the Price over different Groups
for i in categorical:
    if df[i].nunique() < 72:
        f,ax=plt.subplots(figsize=(20,10))
        sns.barplot(df[i],df['msrp'], order = sort_order(i), palette='coolwarm')
        plt.title("Bar Plot of %s" %i, fontsize = 20)
        plt.xticks(fontsize = 12)
        plt.xlabel("%s"%i)
        plt.ylabel("Car Price")
        plt.xticks(fontsize = 15, rotation = 90)
        plt.show();
        print('\n')
# Out:
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\AKSHARA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
#Looping over categorical variables to check the Price over different Groups
for i in categorical:
    if df[i].nunique() < 70:
        f,ax=plt.subplots(figsize=(20,10))
        df[i].value_counts().plot(kind='pie')
        plt.title("Pie Plot of %s" %i, fontsize = 20)
        plt.xticks(fontsize = 12)
        plt.xlabel("%s"%i)
        #plt.ylabel("Car Price")
        plt.xticks(fontsize = 15, rotation = 90)
        plt.show();
        print('\n')
